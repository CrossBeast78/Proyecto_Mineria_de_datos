# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
spotify_df = pd.read_csv('datos\Dados_totais.csv')
genre_index_df = spotify_df.copy()
spotify_df.head()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\memor\AppData\Local\Temp\ipykernel_28628\2213094579.py:7: SyntaxWarning: invalid escape sequence '\D'
#   spotify_df = pd.read_csv('datos\Dados_totais.csv')
#    valence  year  acousticness       artists  danceability  duration_ms  \
# 0    0.285  2000       0.00239      Coldplay         0.429       266773
# 1    0.613  2000       0.14300       OutKast         0.843       270507
# 2    0.400  2000       0.00958   Linkin Park         0.556       216880
# 3    0.543  2000       0.00664  3 Doors Down         0.545       233933
# 4    0.760  2000       0.03020        Eminem         0.949       284200
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# 0   0.661         0  3AJwUDP919kvQ9QcozQPxg          0.000121   11    0.2340
# 1   0.806         1  0I3q5fE6wg7LIfHGngUTnV          0.000000    4    0.0771
# 2   0.864         0  60a0Rd6pjrkxjPbaKzXjfq          0.000000    3    0.2090
# 3   0.865         0  6ZOBP3NvffbU4SZcrnt1k6          0.000011   11    0.1680
# 4   0.661         1  3yfqSUWxFvZELEM4PmlwIR          0.000000    5    0.0454
#
#    loudness  mode                 name  popularity  speechiness    tempo  \
# 0    -7.227     1               Yellow          84       0.0281  173.372
# 1    -5.946     0          Ms. Jackson          80       0.2690   94.948
# 2    -5.870     0           In the End          84       0.0584  105.143
# 3    -5.708     0           Kryptonite          78       0.0286   99.009
# 4    -4.244     0  The Real Slim Shady          80       0.0572  104.504
#
#                    artists_song
# 0             Coldplay - Yellow
# 1         OutKast - Ms. Jackson
# 2      Linkin Park - In the End
# 3     3 Doors Down - Kryptonite
# 4  Eminem - The Real Slim Shady

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20311 entries, 0 to 20310
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   valence           20311 non-null  float64
#  1   year              20311 non-null  int64
#  2   acousticness      20311 non-null  float64
#  3   artists           20311 non-null  object
#  4   danceability      20311 non-null  float64
#  5   duration_ms       20311 non-null  int64
#  6   energy            20311 non-null  float64
#  7   explicit          20311 non-null  int64
#  8   id                20311 non-null  object
#  9   instrumentalness  20311 non-null  float64
#  10  key               20311 non-null  int64
#  11  liveness          20311 non-null  float64
#  12  loudness          20311 non-null  float64
#  13  mode              20311 non-null  int64
#  14  name              20311 non-null  object
#  15  popularity        20311 non-null  int64
#  16  speechiness       20311 non-null  float64
#  17  tempo             20311 non-null  float64
#  18  artists_song      20311 non-null  object
# dtypes: float64(9), int64(6), object(4)
# memory usage: 2.9+ MB

# %%
spotify_df.nunique()
# Out:
# valence              1410
# year                   21
# acousticness         3698
# artists               875
# danceability          946
# duration_ms         13678
# energy               1267
# explicit                2
# id                  20311
# instrumentalness     4123
# key                    12
# liveness             1524
# loudness             9113
# mode                    2
# name                18691
# popularity             77
# speechiness          1269
# tempo               16310
# artists_song        20311
# dtype: int64

# %%
columnas_a_eliminar = ["key", "mode", "loudness", "liveness", "acousticness", "instrumentalness", "speechiness", "duration_ms"]

# Eliminar columnas
spotify_df = spotify_df.drop(columns=columnas_a_eliminar)

columnas_ = ["id", "danceability", "valence", "liveness", "instrumentalness", "loudness"]
genre_index_df = genre_index_df[columnas_]

# %%
spotify_df.head()
# Out:
#    valence  year       artists  danceability  energy  explicit  \
# 0    0.285  2000      Coldplay         0.429   0.661         0
# 1    0.613  2000       OutKast         0.843   0.806         1
# 2    0.400  2000   Linkin Park         0.556   0.864         0
# 3    0.543  2000  3 Doors Down         0.545   0.865         0
# 4    0.760  2000        Eminem         0.949   0.661         1
#
#                        id                 name  popularity    tempo  \
# 0  3AJwUDP919kvQ9QcozQPxg               Yellow          84  173.372
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson          80   94.948
# 2  60a0Rd6pjrkxjPbaKzXjfq           In the End          84  105.143
# 3  6ZOBP3NvffbU4SZcrnt1k6           Kryptonite          78   99.009
# 4  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady          80  104.504
#
#                    artists_song
# 0             Coldplay - Yellow
# 1         OutKast - Ms. Jackson
# 2      Linkin Park - In the End
# 3     3 Doors Down - Kryptonite
# 4  Eminem - The Real Slim Shady

# %%
spotify_df.isnull().sum()
# Out:
# valence         0
# year            0
# artists         0
# danceability    0
# energy          0
# explicit        0
# id              0
# name            0
# popularity      0
# tempo           0
# artists_song    0
# dtype: int64

# %%
def get_gender_index(danceability, valence, liveness, instrumentalness, loudness):
    danceability_index = danceability * 0.161
    valence_index = valence * 0.181
    liveness_index = liveness * 0.153
    instrumentalness_index = instrumentalness * 0.238
    loudness_index = loudness * 0.267
    return danceability_index + valence_index + liveness_index + instrumentalness_index - loudness_index

class GenderIndexCalculator:
    def __init__(self, id, danceability, valence, liveness, instrumentalness, loudness):
        self.id = id
        self.danceability = danceability
        self.valence = valence
        self.liveness = liveness
        self.instrumentalness = instrumentalness
        self.loudness = loudness
    def __str__(self):
        return f"GenderIndex(id={self.id}, danceability={self.danceability}, valence={self.valence}, liveness={self.liveness}, instrumentalness={self.instrumentalness}, loudness={self.loudness})"
    def get_gender_index(self):
        return get_gender_index(self.danceability, self.valence, self.liveness, self.instrumentalness, self.loudness)

# %% [markdown]
# NORMALIZACION DE DATOS

# %%
from sklearn.preprocessing import MinMaxScaler

# Crear el scaler para todas las columnas excepto 'id' y 'loudness'
scaler = MinMaxScaler()
columns_to_normalize = ['danceability', 'valence', 'liveness', 'instrumentalness']
genre_index_df[columns_to_normalize] = scaler.fit_transform(genre_index_df[columns_to_normalize])



# Normalizar loudness por separado para tener valores de 0 a -1
loudness_scaler = MinMaxScaler(feature_range=(-1, 0))
genre_index_df['loudness'] = loudness_scaler.fit_transform(genre_index_df[['loudness']])


genre_index_df.head()
# Out:
#                        id  danceability  valence  liveness  instrumentalness  \
# 0  3AJwUDP919kvQ9QcozQPxg      0.435091    0.285  0.234704          0.000121
# 1  0I3q5fE6wg7LIfHGngUTnV      0.854970    0.613  0.077332          0.000000
# 2  60a0Rd6pjrkxjPbaKzXjfq      0.563895    0.400  0.209629          0.000000
# 3  6ZOBP3NvffbU4SZcrnt1k6      0.552738    0.543  0.168506          0.000011
# 4  3yfqSUWxFvZELEM4PmlwIR      0.962475    0.760  0.045537          0.000000
#
#    loudness
# 0 -0.141665
# 1 -0.120830
# 2 -0.119594
# 3 -0.116959
# 4 -0.093148

# %%
# Luego calculamos los valores
arr_gender_index = []
for i in range(genre_index_df.shape[0]):
    gender_index = GenderIndexCalculator(genre_index_df.iloc[i]['id'], 
                                       genre_index_df.iloc[i]['danceability'],
                                       genre_index_df.iloc[i]['valence'], 
                                       genre_index_df.iloc[i]['liveness'],
                                       genre_index_df.iloc[i]['instrumentalness'],
                                       genre_index_df.iloc[i]['loudness'])
    arr_gender_index.append(gender_index.get_gender_index())

genre_index_df['genre_index'] = arr_gender_index

scaler = MinMaxScaler(feature_range=(0, 1))
normalizar_gender_index = scaler.fit_transform(genre_index_df[['genre_index']])
genre_index_df['genre_index'] = normalizar_gender_index
genre_index_df.head()
# Out:
#                        id  danceability  valence  liveness  instrumentalness  \
# 0  3AJwUDP919kvQ9QcozQPxg      0.435091    0.285  0.234704          0.000121
# 1  0I3q5fE6wg7LIfHGngUTnV      0.854970    0.613  0.077332          0.000000
# 2  60a0Rd6pjrkxjPbaKzXjfq      0.563895    0.400  0.209629          0.000000
# 3  6ZOBP3NvffbU4SZcrnt1k6      0.552738    0.543  0.168506          0.000011
# 4  3yfqSUWxFvZELEM4PmlwIR      0.962475    0.760  0.045537          0.000000
#
#    loudness  genre_index
# 0 -0.141665     0.200389
# 1 -0.120830     0.365476
# 2 -0.119594     0.254334
# 3 -0.116959     0.283338
# 4 -0.093148     0.419193

# %%
gender_index_simple = genre_index_df[['id', 'genre_index']]


resultado = pd.merge(spotify_df, gender_index_simple, on='id')
resultado.head()
# Out:
#    valence  year       artists  danceability  energy  explicit  \
# 0    0.285  2000      Coldplay         0.429   0.661         0
# 1    0.613  2000       OutKast         0.843   0.806         1
# 2    0.400  2000   Linkin Park         0.556   0.864         0
# 3    0.543  2000  3 Doors Down         0.545   0.865         0
# 4    0.760  2000        Eminem         0.949   0.661         1
#
#                        id                 name  popularity    tempo  \
# 0  3AJwUDP919kvQ9QcozQPxg               Yellow          84  173.372
# 1  0I3q5fE6wg7LIfHGngUTnV          Ms. Jackson          80   94.948
# 2  60a0Rd6pjrkxjPbaKzXjfq           In the End          84  105.143
# 3  6ZOBP3NvffbU4SZcrnt1k6           Kryptonite          78   99.009
# 4  3yfqSUWxFvZELEM4PmlwIR  The Real Slim Shady          80  104.504
#
#                    artists_song  genre_index
# 0             Coldplay - Yellow     0.200389
# 1         OutKast - Ms. Jackson     0.365476
# 2      Linkin Park - In the End     0.254334
# 3     3 Doors Down - Kryptonite     0.283338
# 4  Eminem - The Real Slim Shady     0.419193

# %%
class Cancion_normalizada: 
    def __init__ (self, valence, danceability, energy, id, popularity, tempo, genre_index):
        self.valence = valence
        self.danceability = danceability
        self.energy = energy
        self.id = id
        self.popularity = popularity
        self.tempo = tempo
        self.genre_index = genre_index
    def __str__(self):
        return f"Cancion(valence={self.valence}, danceability={self.danceability}, energy={self.energy}, id={self.id}, popularity={self.popularity}, tempo={self.tempo}, genre_index={self.genre_index})"
    def compare_song_index(self, other):
        dist = (
            0.4 * (abs(self.genre_index - other.genre_index)) +
            0.1 * abs(self.valence - other.valence) +
            0.1 * abs(self.danceability - other.danceability) +
            0.1 * abs(self.energy - other.energy) +
            0.1 * (abs(self.popularity - other.popularity)) +
            0.1 * (abs(self.tempo - other.tempo)) 
        )
        return 1/(1+dist)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
resultado_normalizado = resultado.copy()
resultado_normalizado = resultado_normalizado.drop(columns=[ 'name', 'artists', 'year', 'explicit', 'artists_song'])
resultado_normalizado.set_index('id', inplace=True)
resultado_normalizado[resultado_normalizado.columns] = scaler.fit_transform(resultado_normalizado[resultado_normalizado.columns])

# %%
def calcular_similitud(resultado_normalizado, song_id):
    if song_id not in resultado_normalizado.index:
        raise KeyError(f"ID '{song_id}' no encontrado en el DataFrame.")
    target_row = resultado_normalizado.loc[song_id]

    target = Cancion_normalizada(
        target_row['valence'],
        target_row['danceability'],
        target_row['energy'],
        song_id,
        target_row['popularity'],
        target_row['tempo'],
        target_row['genre_index']
    )

    similitudes = {}

    for other_id, row in resultado_normalizado.iterrows():
        other = Cancion_normalizada(
            row['valence'],
            row['danceability'],
            row['energy'],
            other_id,
            row['popularity'],
            row['tempo'],
            row['genre_index']
        )
        similitudes[other_id] = target.compare_song_index(other)

    return similitudes

print(calcular_similitud(resultado_normalizado, '3AJwUDP919kvQ9QcozQPxg'))
# Out:
# {'3AJwUDP919kvQ9QcozQPxg': np.float64(1.0), '0I3q5fE6wg7LIfHGngUTnV': np.float64(0.8368422031232442), '60a0Rd6pjrkxjPbaKzXjfq': np.float64(0.9113461705468859), '6ZOBP3NvffbU4SZcrnt1k6': np.float64(0.884211814831104), '3yfqSUWxFvZELEM4PmlwIR': np.float64(0.8176284789063105), '40rvBMQizxkIqnjPdEWY1v': np.float64(0.8012995046515631), '3Gf5nttwcX9aaSQXRWidEZ': np.float64(0.8117065436912037), '3UmaczJpikHgJFyBTAJVoz': np.float64(0.8305109052031251), '62bOmKYxYg7dhrC6gH9vFn': np.float64(0.8446235898343405), '6naxalmIoLFWR0siv8dnQQ': np.float64(0.7872263180881777), '7D0RhFcb3CrfPuTJ0obrod': np.float64(0.8951901147822442), '3K4HG9evC7dg3N0R9cYqk4': np.float64(0.893130937084391), '3WkibOpDF7cQ5xntM1epyf': np.float64(0.8184012771643046), '3wMUvT6eIw2L5cZFG1yH9j': np.float64(0.8596779883557608), '0aym2LBJBk9DAYuHHutrIl': np.float64(0.9379968825608321), '4pbG9SUmWIvsROVLF0zF9s': np.float64(0.84655859491314), '0wqOReZDnrefefEsrIGeR4': np.float64(0.9117242006934707), '57BrRMwf9LrcmuOsyGilwr': np.float64(0.9026592574428454), '6glsMWIMIxQ4BedzLqGVi4': np.float64(0.8246946916211774), '2g2GkH3vZHk4lWzBjgQ6nY': np.float64(0.7879210969258036), '3IV4swNduIRunHREK80owz': np.float64(0.8408187367773442), '7FDV5ELOJHCGLe52AnttEd': np.float64(0.8522747396523097), '23wfXwnsPZYe5A1xXRHb3J': np.float64(0.8697022165723239), '51c94ac31swyDQj9B3Lzs3': np.float64(0.8873839729743991), '1Vej0qeQ3ioKwpI6FUbRv1': np.float64(0.8436820475145047), '2AW37v0bDyuOzGP3XnmFuA': np.float64(0.8349267726459241), '0YWUHZPJVg4iujddsJDwhM': np.float64(0.8534287479360808), '